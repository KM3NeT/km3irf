# %% [markdown]
# This notebook needs for checking tests

# %%
import matplotlib.pyplot as plt
from km3irf.test_utils import mpl_plot_check


# Define a function that creates a plot
def create_sample_plot():
    x = [1, 2, 3, 4, 5, 8]
    y = [10, 12, 5, 8, 9, 11, 13]
    plt.plot(x, y)
    plt.xlabel("X-axis")
    plt.ylabel("Y-axis")
    plt.title("Sample Plot")

    # plt.invalid_function()


# Test the plot using mpl_plot_check
# with mpl_plot_check():
#     create_sample_plot()

# At this point, the plot has been created and saved in memory as a PNG.
# You can continue with your testing or other tasks.

# %%
import numpy as np

np.random.seed(0)
np.random.random((2, 2, 2))
# Out:
# array([[[0.5488135 , 0.71518937],
#         [0.60276338, 0.54488318]],
#
#        [[0.4236548 , 0.64589411],
#         [0.43758721, 0.891773  ]]])

# %%
create_sample_plot()

# %%
import km3irf

km3irf.__version__
from os.path import join

# %%
aeff = km3irf.utils.DrawAeff(aeff_path="aeff_new.fits")
aeff.peek()

# %%
aeff = km3irf.utils.DrawAeff(aeff_path=join(km3irf.utils.data_dir, "aeff.fits"))
aeff.peek()
