# %% [markdown]
# ## Test of PSF from gammapy
#
# two modules were copied from `gammapy v0.17`
# - `psf_3d.py`
# - `psf_table.py`
#
# Dependencies from `gammapy` were illiminated.

# %%
import km3irf

# %%
km3irf.__version__
# Out:
# '0.3.1.dev30+gadee277.d20230519'

# %%
km3irf.list_data()
# Out:
# {'aeff.fits': '/home/msmirnov/working_space/km3irf/src/km3irf/data/aeff.fits',
#  'aeff_nocuts.fits': '/home/msmirnov/working_space/km3irf/src/km3irf/data/aeff_nocuts.fits',
#  'bkg_mu.fits': '/home/msmirnov/working_space/km3irf/src/km3irf/data/bkg_mu.fits',
#  'bkg_nu.fits': '/home/msmirnov/working_space/km3irf/src/km3irf/data/bkg_nu.fits',
#  'bkg_nu_knee_correction_test.fits': '/home/msmirnov/working_space/km3irf/src/km3irf/data/bkg_nu_knee_correction_test.fits',
#  'edisp.fits': '/home/msmirnov/working_space/km3irf/src/km3irf/data/edisp.fits',
#  'edisp_no_norm.fits': '/home/msmirnov/working_space/km3irf/src/km3irf/data/edisp_no_norm.fits',
#  'edisp_no_smooth_no_norm.fits': '/home/msmirnov/working_space/km3irf/src/km3irf/data/edisp_no_smooth_no_norm.fits',
#  'psf.fits': '/home/msmirnov/working_space/km3irf/src/km3irf/data/psf.fits',
#  'psf_no_norm.fits': '/home/msmirnov/working_space/km3irf/src/km3irf/data/psf_no_norm.fits',
# ...

# %%
psf_km3 = km3irf.PSF3D.read(path_to_file="/home/msmirnov/working_space/km3irf/src/km3irf/data/psf.fits")

# %%
psf_km3.peek()
